# %% [markdown]
# <h1>Custom Image Classification</h1>
#
# In the real world the data we are using will not be nicely formatted as part of a library, it is likely that we will be creating our own datasets. In this example we are exploring a realistic binary classification problem.
#
# Let's explore what its like to work with a more realistic data set. The dataset has been taken from Kaggle and there are 12,500 images of both cats and dogs (this is a large dataset).<br/><br/>
# <h2>Visualising Image Data</h2>

# %%
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 788D-4171
#
#  Directory of C:\Users\faisa\OneDrive - Letterkenny Institute of Technology\3rd Semester\AI 2- James, Kevin\Computer Vision\Practicals\Week 5\Practical 5b
#
# 22-05-2020  02:25    <DIR>          .
# 22-05-2020  02:25    <DIR>          ..
# 22-05-2020  01:45    <DIR>          .ipynb_checkpoints
# 22-05-2020  01:04        29,138,192 cat_dog_classifier100ep-150st.h5
# 22-05-2020  01:45    <DIR>          CATS_DOGS
# 22-05-2020  01:18       811,938,720 CATS_DOGS.zip
# 22-05-2020  01:04         1,241,925 cattest1.jpg
# 22-05-2020  01:04           519,107 cattest2.jpg
# 22-05-2020  02:25           561,476 ComputerVision_Week5b.ipynb
# 22-05-2020  01:30    <DIR>          YOLO
# 22-05-2020  01:15       235,181,693 YOLO.zip
#                6 File(s)  1,078,581,113 bytes
#                5 Dir(s)  84,500,901,888 bytes free

# %%
cat1 = cv2.imread('CATS_DOGS/train/CAT/1.jpg')
cat1 = cv2.cvtColor(cat1,cv2.COLOR_BGR2RGB)

# %%
type(cat1)
# Out:
# numpy.ndarray

# %%
cat1.shape
# Out:
# (281, 300, 3)

# %%
plt.imshow(cat1)

# %%
dog1 = cv2.imread('CATS_DOGS/train/Dog/1.jpg')
dog1 = cv2.cvtColor(dog1,cv2.COLOR_BGR2RGB)

# %%
dog1.shape
# Out:
# (500, 327, 3)

# %%
plt.imshow(dog1)

# %% [markdown]
# <h2>Preparing the Data for the model</h2>
#
# There is too much data for us to read all at once in memory. We can use some built in Keras functions to automatically process the data, generate a flow of batches from a directory and manipulate the images.
#
# <b>Image Manipulation</b>
#
# It is standard practice to manipulate the images with rotation, resizing, and scaling so the model becomes more robust to different images that the data set doesn't represent. We can use the **ImageDataGenerator** to do this automatically.

# %%
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.
# C:\Users\faisa\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\faisa\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\faisa\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\faisa\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\faisa\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\faisa\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
image_gen = ImageDataGenerator(rotation_range=30, # rotate the image 30 degrees
                               width_shift_range=0.1, # Shift the pic width by a max of 10%
                               height_shift_range=0.1, # Shift the pic height by a max of 10%
                               rescale=1/255, # Rescale the image by normalzing it.
                               shear_range=0.2, # Shear means cutting away part of the image (max 20%)
                               zoom_range=0.2, # Zoom in by 20% max
                               horizontal_flip=True, # Allo horizontal flipping
                               fill_mode='nearest' # Fill in missing pixels with the nearest filled value
                              )

# %%
plt.imshow(image_gen.random_transform(dog1))

# %%
plt.imshow(image_gen.random_transform(dog1))

# %%
plt.imshow(image_gen.random_transform(dog1))

# %% [markdown]
# <b>Manipulating images automatically from directory</b>
#
# In order to use .flow_from_directory, you must organise the images in sub-directories. The directories should only contain images of one class, so one folder per class of images.
#
# Structure Needed:
#
# * Image Data Folder
#     * Class 1
#         * 0.jpg
#         * 1.jpg
#         * ...
#     * Class 2
#         * 0.jpg
#         * 1.jpg
#         * ...
#     * ...
#     * Class n

# %%
image_gen.flow_from_directory('CATS_DOGS/train')
# Out:
# Found 18743 images belonging to 2 classes.

# %%
image_gen.flow_from_directory('CATS_DOGS/test')
# Out:
# Found 6251 images belonging to 2 classes.

# %% [markdown]
# <b>Resizing Images</b>
#
# Keras can resize all the images to 150 pixels by 150 pixels once they've been manipulated so they are all a standard size for analysis.

# %%
# width,height,channels
image_shape = (150,150,3)

# %% [markdown]
# <h2>Building the Model</h2>

# %%
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D

# %%
model = Sequential()

model.add(Conv2D(filters=32, kernel_size=(3,3),input_shape=(150,150,3), activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=(150,150,3), activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=(150,150,3), activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Flatten())


model.add(Dense(128))
model.add(Activation('relu'))

# Dropouts help reduce overfitting by randomly turning neurons off during training.
# Here we say randomly turn off 50% of neurons.
model.add(Dropout(0.5))

# Last layer, remember its binary, 0=cat , 1=dog
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\faisa\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 34, 34, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18496)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               2367616
# _________________________________________________________________
# activation_1 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# _________________________________________________________________
# activation_2 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 2,424,065
# Trainable params: 2,424,065
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <h2>Training the Model</h2>

# %%
batch_size = 16

train_image_gen = image_gen.flow_from_directory('CATS_DOGS/train',
                                               target_size=image_shape[:2],
                                               batch_size=batch_size,
                                               class_mode='binary')
# Out:
# Found 18743 images belonging to 2 classes.

# %%
test_image_gen = image_gen.flow_from_directory('CATS_DOGS/test',
                                               target_size=image_shape[:2],
                                               batch_size=batch_size,
                                               class_mode='binary')
# Out:
# Found 6251 images belonging to 2 classes.

# %%
train_image_gen.class_indices
# Out:
# {'CAT': 0, 'DOG': 1}

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
results = model.fit_generator(train_image_gen,epochs=100,
                              steps_per_epoch=150,
                              validation_data=test_image_gen,
                             validation_steps=12)
# Out:
# WARNING:tensorflow:From C:\Users\faisa\anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 150/150 [==============================] - 143s 955ms/step - loss: 0.6964 - accuracy: 0.5233 - val_loss: 0.6942 - val_accuracy: 0.5833
# Epoch 2/100
# 150/150 [==============================] - 150s 1s/step - loss: 0.6830 - accuracy: 0.5442 - val_loss: 0.8165 - val_accuracy: 0.5312
# Epoch 3/100
# 150/150 [==============================] - 166s 1s/step - loss: 0.6836 - accuracy: 0.5621 - val_loss: 0.6735 - val_accuracy: 0.5885
# Epoch 4/100
# 150/150 [==============================] - 154s 1s/step - loss: 0.6777 - accuracy: 0.5562 - val_loss: 0.6928 - val_accuracy: 0.5521
# Epoch 5/100
# 150/150 [==============================] - 146s 976ms/step - loss: 0.6839 - accuracy: 0.5667 - val_loss: 0.6820 - val_accuracy: 0.6198
# Epoch 6/100
# 150/150 [==============================] - 155s 1s/step - loss: 0.6747 - accuracy: 0.5958 - val_loss: 0.5305 - val_accuracy: 0.6458
# Epoch 7/100
# 150/150 [==============================] - 144s 960ms/step - loss: 0.6783 - accuracy: 0.5922 - val_loss: 0.7054 - val_accuracy: 0.5885
# Epoch 8/100
# 150/150 [==============================] - 130s 869ms/step - loss: 0.6589 - accuracy: 0.6102 - val_loss: 0.5744 - val_accuracy: 0.6615
# Epoch 9/100
# 150/150 [==============================] - 118s 787ms/step - loss: 0.6579 - accuracy: 0.6279 - val_loss: 0.6628 - val_accuracy: 0.6927
# Epoch 10/100
# 150/150 [==============================] - 120s 799ms/step - loss: 0.6508 - accuracy: 0.6263 - val_loss: 0.5595 - val_accuracy: 0.6719
# Epoch 11/100
# 150/150 [==============================] - 118s 789ms/step - loss: 0.6470 - accuracy: 0.6329 - val_loss: 0.5712 - val_accuracy: 0.6771
# Epoch 12/100
# 150/150 [==============================] - 115s 770ms/step - loss: 0.6261 - accuracy: 0.6554 - val_loss: 0.6417 - val_accuracy: 0.6302
# Epoch 13/100
# 150/150 [==============================] - 118s 790ms/step - loss: 0.6263 - accuracy: 0.6442 - val_loss: 0.5370 - val_accuracy: 0.6510
# Epoch 14/100
# 150/150 [==============================] - 124s 824ms/step - loss: 0.6095 - accuracy: 0.6654 - val_loss: 0.6838 - val_accuracy: 0.6667
# Epoch 15/100
# 150/150 [==============================] - 128s 855ms/step - loss: 0.5935 - accuracy: 0.6975 - val_loss: 0.6447 - val_accuracy: 0.7135
# Epoch 16/100
# 150/150 [==============================] - 122s 812ms/step - loss: 0.5979 - accuracy: 0.6817 - val_loss: 0.7521 - val_accuracy: 0.6458
# Epoch 17/100
# 150/150 [==============================] - 123s 821ms/step - loss: 0.5762 - accuracy: 0.7017 - val_loss: 0.7844 - val_accuracy: 0.6510
# Epoch 18/100
# 150/150 [==============================] - 123s 819ms/step - loss: 0.5793 - accuracy: 0.7038 - val_loss: 0.6121 - val_accuracy: 0.7396
# Epoch 61/100
# 150/150 [==============================] - 191s 1s/step - loss: 0.4459 - accuracy: 0.7900 - val_loss: 0.5357 - val_accuracy: 0.7708
# Epoch 62/100
# 150/150 [==============================] - 200s 1s/step - loss: 0.4759 - accuracy: 0.7750 - val_loss: 0.4631 - val_accuracy: 0.8177
# Epoch 63/100
# 150/150 [==============================] - 160s 1s/step - loss: 0.4472 - accuracy: 0.7858 - val_loss: 0.4258 - val_accuracy: 0.7969
# Epoch 64/100
# 150/150 [==============================] - 198s 1s/step - loss: 0.4469 - accuracy: 0.7879 - val_loss: 0.3868 - val_accuracy: 0.7448
# Epoch 65/100
# 150/150 [==============================] - 168s 1s/step - loss: 0.4525 - accuracy: 0.7996 - val_loss: 0.4460 - val_accuracy: 0.7865
# Epoch 66/100
# 150/150 [==============================] - 199s 1s/step - loss: 0.4435 - accuracy: 0.7946 - val_loss: 0.5569 - val_accuracy: 0.7594
# Epoch 67/100
# 150/150 [==============================] - 161s 1s/step - loss: 0.4316 - accuracy: 0.7917 - val_loss: 0.1910 - val_accuracy: 0.7969
# Epoch 68/100
# 150/150 [==============================] - 190s 1s/step - loss: 0.4563 - accuracy: 0.7880 - val_loss: 0.7333 - val_accuracy: 0.7812
# Epoch 69/100
# 150/150 [==============================] - 155s 1s/step - loss: 0.4622 - accuracy: 0.7883 - val_loss: 0.2575 - val_accuracy: 0.8750
# Epoch 70/100
# 150/150 [==============================] - 162s 1s/step - loss: 0.4280 - accuracy: 0.8133 - val_loss: 0.4782 - val_accuracy: 0.8177
# Epoch 71/100
# 150/150 [==============================] - 195s 1s/step - loss: 0.4563 - accuracy: 0.7837 - val_loss: 0.6242 - val_accuracy: 0.7292
# Epoch 72/100
# 150/150 [==============================] - 163s 1s/step - loss: 0.4275 - accuracy: 0.8087 - val_loss: 0.3482 - val_accuracy: 0.8073
# Epoch 73/100
# 150/150 [==============================] - 159s 1s/step - loss: 0.4230 - accuracy: 0.8150 - val_loss: 0.4158 - val_accuracy: 0.7969
# Epoch 74/100
# 150/150 [==============================] - 158s 1s/step - loss: 0.4418 - accuracy: 0.7992 - val_loss: 0.2860 - val_accuracy: 0.8177
# Epoch 75/100
# 150/150 [==============================] - 154s 1s/step - loss: 0.4365 - accuracy: 0.8122 - val_loss: 0.5565 - val_accuracy: 0.7708
# Epoch 76/100
# 150/150 [==============================] - 157s 1s/step - loss: 0.4422 - accuracy: 0.7983 - val_loss: 0.4418 - val_accuracy: 0.8229
# Epoch 77/100
# 150/150 [==============================] - 157s 1s/step - loss: 0.4294 - accuracy: 0.7983 - val_loss: 0.6450 - val_accuracy: 0.7240
# Epoch 78/100
# 150/150 [==============================] - 157s 1s/step - loss: 0.4375 - accuracy: 0.7967 - val_loss: 0.5327 - val_accuracy: 0.8333
# Epoch 79/100
# 150/150 [==============================] - 155s 1s/step - loss: 0.4327 - accuracy: 0.8008 - val_loss: 0.6117 - val_accuracy: 0.8490
# Epoch 80/100
# 150/150 [==============================] - 157s 1s/step - loss: 0.4270 - accuracy: 0.8054 - val_loss: 0.3653 - val_accuracy: 0.8281
# Epoch 81/100
# 150/150 [==============================] - 184s 1s/step - loss: 0.4202 - accuracy: 0.8075 - val_loss: 0.2824 - val_accuracy: 0.7656
# Epoch 82/100
# 150/150 [==============================] - 132s 879ms/step - loss: 0.4136 - accuracy: 0.8054 - val_loss: 0.4392 - val_accuracy: 0.8281
# Epoch 83/100
# 150/150 [==============================] - 157s 1s/step - loss: 0.4293 - accuracy: 0.7921 - val_loss: 0.4715 - val_accuracy: 0.8125
# Epoch 84/100
# 150/150 [==============================] - 158s 1s/step - loss: 0.4217 - accuracy: 0.7992 - val_loss: 0.3040 - val_accuracy: 0.8542
# Epoch 85/100
# 150/150 [==============================] - 159s 1s/step - loss: 0.4251 - accuracy: 0.8026 - val_loss: 0.3992 - val_accuracy: 0.8490
# Epoch 86/100
# 150/150 [==============================] - 153s 1s/step - loss: 0.4180 - accuracy: 0.8129 - val_loss: 0.3363 - val_accuracy: 0.8229
# Epoch 87/100
# 150/150 [==============================] - 159s 1s/step - loss: 0.4300 - accuracy: 0.8046 - val_loss: 0.2948 - val_accuracy: 0.8490
# Epoch 88/100
# 150/150 [==============================] - 161s 1s/step - loss: 0.4057 - accuracy: 0.8208 - val_loss: 0.4722 - val_accuracy: 0.7604
# Epoch 89/100
# 150/150 [==============================] - 153s 1s/step - loss: 0.4171 - accuracy: 0.8138 - val_loss: 0.4530 - val_accuracy: 0.8125
# Epoch 90/100
# 150/150 [==============================] - 129s 859ms/step - loss: 0.4295 - accuracy: 0.8084 - val_loss: 0.1424 - val_accuracy: 0.8177
# Epoch 91/100
# 150/150 [==============================] - 161s 1s/step - loss: 0.3868 - accuracy: 0.8304 - val_loss: 0.4383 - val_accuracy: 0.7917
# Epoch 92/100
# 150/150 [==============================] - 157s 1s/step - loss: 0.3964 - accuracy: 0.8192 - val_loss: 0.4900 - val_accuracy: 0.7448
# Epoch 93/100
# 150/150 [==============================] - 156s 1s/step - loss: 0.3970 - accuracy: 0.8250 - val_loss: 0.4640 - val_accuracy: 0.8281
# Epoch 94/100
# 150/150 [==============================] - 156s 1s/step - loss: 0.4168 - accuracy: 0.8125 - val_loss: 0.3755 - val_accuracy: 0.8333
# Epoch 95/100
# 150/150 [==============================] - 131s 876ms/step - loss: 0.3987 - accuracy: 0.8279 - val_loss: 0.3728 - val_accuracy: 0.7917
# Epoch 96/100
# 150/150 [==============================] - 155s 1s/step - loss: 0.3874 - accuracy: 0.8292 - val_loss: 0.2554 - val_accuracy: 0.8542
# Epoch 97/100
# 150/150 [==============================] - 158s 1s/step - loss: 0.4132 - accuracy: 0.8200 - val_loss: 0.3472 - val_accuracy: 0.8229
# Epoch 98/100
# 150/150 [==============================] - 157s 1s/step - loss: 0.4053 - accuracy: 0.8193 - val_loss: 0.8391 - val_accuracy: 0.7273
# Epoch 99/100
# 150/150 [==============================] - 126s 840ms/step - loss: 0.4109 - accuracy: 0.8087 - val_loss: 0.3167 - val_accuracy: 0.7865
# Epoch 100/100
# 150/150 [==============================] - 154s 1s/step - loss: 0.3764 - accuracy: 0.8296 - val_loss: 0.4337 - val_accuracy: 0.7969

# %%
model.save('cat_dog_classifier100ep-150st.h5')

# %% [markdown]
# <h2>Measuring the Model Results</h2>

# %%
results.history['val_accuracy']
# Out:
# [0.5833333134651184,
#  0.53125,
#  0.5885416865348816,
#  0.5520833134651184,
#  0.6197916865348816,
#  0.6458333134651184,
#  0.5885416865348816,
#  0.6614583134651184,
#  0.6927083134651184,
#  0.671875,
#  0.6770833134651184,
#  0.6302083134651184,
#  0.6510416865348816,
#  0.6666666865348816,
#  0.7135416865348816,
#  0.6458333134651184,
#  0.6510416865348816,
#  0.7395833134651184,
#  0.734375,
#  0.6875,
#  0.7291666865348816,
#  0.7291666865348816,
#  0.7291666865348816,
#  0.7552083134651184,
#  0.671875,
#  0.6927083134651184,
#  0.734375,
#  0.7708333134651184,
#  0.7708333134651184,
#  0.6927083134651184,
#  0.7291666865348816,
#  0.7604166865348816,
#  0.7540106773376465,
#  0.7291666865348816,
#  0.734375,
#  0.7552083134651184,
#  0.765625,
#  0.7864583134651184,
#  0.8125,
#  0.8020833134651184,
#  0.8072916865348816,
#  0.7552083134651184,
#  0.8125,
#  0.78125,
#  0.765625,
#  0.765625,
#  0.78125,
#  0.8072916865348816,
#  0.71875,
#  0.7916666865348816,
#  0.8072916865348816,
#  0.8072916865348816,
#  0.765625,
#  0.7864583134651184,
#  0.8072916865348816,
#  0.7916666865348816,
#  0.8177083134651184,
#  0.828125,
#  0.7447916865348816,
#  0.7760416865348816,
#  0.7708333134651184,
#  0.8177083134651184,
#  0.796875,
#  0.7447916865348816,
#  0.7864583134651184,
#  0.759358286857605,
#  0.796875,
#  0.78125,
#  0.875,
#  0.8177083134651184,
#  0.7291666865348816,
#  0.8072916865348816,
#  0.796875,
#  0.8177083134651184,
#  0.7708333134651184,
#  0.8229166865348816,
#  0.7239583134651184,
#  0.8333333134651184,
#  0.8489583134651184,
#  0.828125,
#  0.765625,
#  0.828125,
#  0.8125,
#  0.8541666865348816,
#  0.8489583134651184,
#  0.8229166865348816,
#  0.8489583134651184,
#  0.7604166865348816,
#  0.8125,
#  0.8177083134651184,
#  0.7916666865348816,
#  0.7447916865348816,
#  0.828125,
#  0.8333333134651184,
#  0.7916666865348816,
#  0.8541666865348816,
#  0.8229166865348816,
#  0.7272727489471436,
#  0.7864583134651184,
#  0.796875]

# %%
plt.plot(results.history['val_accuracy'])

# %% [markdown]
# <h2>Predicting</h2>

# %%
train_image_gen.class_indices
# Out:
# {'CAT': 0, 'DOG': 1}

# %%
import numpy as np
from keras.preprocessing import image

cat_imgfile = 'cattest1.jpg'

catimg = image.load_img(cat_imgfile, target_size=(150, 150))

catimg = image.img_to_array(catimg)

catimg = np.expand_dims(catimg, axis=0)
catimg= catimg/255

# %%
prediction_prob = model.predict(catimg)

# %%
# Output prediction
print(f'Probability that image is a Cat is: {prediction_prob} ')
# Out:
# Probability that image is a Cat is: [[0.48832846]]

# %%
import numpy as np
from keras.preprocessing import image

cat_imgfile = 'cattest2.jpg'

catimg = image.load_img(cat_imgfile, target_size=(150, 150))

catimg = image.img_to_array(catimg)

catimg = np.expand_dims(catimg, axis=0)
catimg= catimg/255
prediction_prob = model.predict(catimg)
print(f'Probability that image is a Cat is: {prediction_prob} ')
# Out:
# Probability that image is a Cat is: [[0.7332015]]

# %% [markdown]
# <h1>Challenge: Try a lower number of Epochs</h1><br/>
# It will take less time to run but the performance of the network may not be as effective.<br/>
# Try passing different images in for prediction, are there any surprises?<br/>
# There are many binary classification datasets on Kaggle, try this notebook with a new dataset.
